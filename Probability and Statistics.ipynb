# %% [markdown]
# ## Q-Q PLOT

# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt

x = np.random.normal(loc = 20,scale = 5 ,size = 100) #mean = 20 , standard deviation = 5
sp.stats.probplot(x,dist="norm",plot=matplotlib.pyplot)
plt.grid()

# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt

x = np.random.normal(loc = 20,scale = 5 ,size = 1000) #mean = 20 , standard deviation = 5
sp.stats.probplot(x,dist="norm",plot=matplotlib.pyplot)
plt.grid()

# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt

x = np.random.normal(loc = 20,scale = 5 ,size = 10000) #mean = 20 , standard deviation = 5
sp.stats.probplot(x,dist="norm",plot=matplotlib.pyplot)
plt.grid()

# %%
import seaborn as sns

x = np.random.exponential(scale = 1.0,size = 1000)
sns.set()
ax = sns.distplot(x)
plt.show()

# %%
stats.probplot(x,dist="norm",plot=plt)
plt.grid()

# %% [markdown]
# This shows that its not a gaussian distribution

# %% [markdown]
# ## BOX-COX

# %%
x_t,l = stats.boxcox(x)
print(l)

stats.probplot(x_t,dist="norm",plot=plt)
plt.grid()
# Out:
# 0.24385736791367255

# %%
sns.set()
sns.distplot(x_t)

kwargs = {'cumulative':True}
sns.distplot(x_t,hist_kws=kwargs,kde_kws=kwargs)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-e2ae83661206> in <module>
#       3
#       4 kwargs = {'cumulative':True}
# ----> 5 sns.distplot(x_t,hist_kws=kwargs,kde_kws=kwargs)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# ...

# %%
x = np.random.pareto(a=2.0,size=1000)

sns.set()
ax = sns.distplot(x)

kwargs = {'cumulative':True}
sns.distplot(x,hist_kws=kwargs,kde_kws=kwargs)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-47ffd7a1c4aa> in <module>
#       5
#       6 kwargs = {'cumulative':True}
# ----> 7 sns.distplot(x,hist_kws=kwargs,kde_kws=kwargs)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# ...

# %%
x_t,l = stats.boxcox(x)
print(l)

stats.probplot(x_t,dist="norm",plot=plt)
plt.grid()
# Out:
# 0.09372289589903499

# %%
sns.set()
sns.distplot(x_t)

k = {'cumulative':True}
sns.distplot(x_t,hist_kws = k,kde_kws=k)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-5e35f610b158> in <module>
#       3
#       4 k = {'cumulative':True}
# ----> 5 sns.distplot(x_t,hist_kws = k,kde_kws=k)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# ...

# %% [markdown]
# ## Bootstrapping
