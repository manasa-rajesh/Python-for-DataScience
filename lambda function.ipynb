# %%
double = lambda x:x*2
print(double(5))
# Out:
# 10

# %%
lst=[1,2,3,4,5]
even_lst = list(filter(lambda x:(x%2==0),lst))
print(even_lst)
# Out:
# [2, 4]

# %%
lst=[1,2,3,4,5]
new_lst= list(map(lambda x:(x**2),lst))
print(new_lst)
# Out:
# [1, 4, 9, 16, 25]
